# %% [markdown]
# ## <span style="color:#4375c7">Data and AI in Economics</span>
# ***
# *The course material is for educational purposes only. Nothing herein should be taken as an investment advice or  offers any opinion  <br/> with respect to the suitability of any security. To obtain further information about this course, [contact us](http://wp.firrm.de/) or visit us during [office hours](https://www.finance.wiwi.tu-dortmund.de/cms/index.php/homepage/kalender).*
# ***
#
#
# ## Causal Inference

# %% [markdown]
# ## 2. Hands-on session <a id='ho'></a>
#
# ### Exercise 1
# The following exercise is based on a (real-world) example by Allen Downey to demonstrate Simpson's Paradox.
#
# In 2021, a journalist (The Atlantic magazine identified him as "The Pandemic's Wrongest Man") wrote a series of misleading articles about the COVID pandemic. In November, this journalist posted an online newsletter with the title "Vaccinated English adults under 60 are dying at twice the rate of unvaccinated people the same age". It includes a graph showing that the overall death rate among young, vaccinated people increased between April and September, 2021, and was actually higher among the vaccinated than among the unvaccinated.
#
# As you might expect, this newsletter got a lot of attention. Among skeptics, it seemed like proof that vaccines were not just ineffective, but harmful. And among people who were counting on vaccines to end the pandemic, it seemed like a devastating setback.
#
# Many people fact-checked the article, and at first the results held up to scrutiny: the graph accurately represented data published by the U.K. Office for National Statistics. Specifically, it showed death rates, from any cause, for people in England between 10 and 59 years old, from March to September 2021. And between April and September, these rates were higher among the fully vaccinated, compared to the unvaccinated, by a factor of almost 2. So the journalist's description of the results was correct.
#
# However, his conclusion that vaccines were causing increased mortality was completely wrong. In fact, the data he reported shows that vaccines were safe and effective in this population, and demonstrably saved many lives.
#
# How, you might ask, can increased mortality be evidence of saved lives? The answer is Simpson's paradox.
#
# Let's look at the data and disenchant what the original article suggested.
#
# 1. [This link](https://substackcdn.com/image/fetch/f_auto,q_auto:good,fl_progressive:steep/https%3A%2F%2Fbucketeer-e05bbc84-baa3-437e-9518-adb32be77984.s3.amazonaws.com%2Fpublic%2Fimages%2Fbdca5329-b20b-4518-a733-fff84cc22124_1098x681.png) features the graph that was presented in the article. Use the dataset "datasetfinalcorrected3.xlsx" from the [U.K. Office for National Statistics](https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths/datasets/deathsbyvaccinationstatusengland/deathsoccurringbetween2januaryand24september2021/datasetfinalcorrected3.xlsx) to replicate the graph, beginning on 19 March 2021!
# <br>
# 2. The journalist concludes: "Vaccinated people under 60 are twice as likely to die as unvaccinated people. And overall deaths in Britain are running well above normal. I don't know how to explain this other than vaccine-caused mortality." Did you realize, when replicating his graph, what has paved the way for this wrongful conclusion?
# <br>
# 3. Now, use the whole available time range (1 January - 30 September 2021) and show the same graph for the other age groups as well!
# <br>
# 4. So what explains the apparent reversal among people between 10 and 59 years old? Simpson's Paradox! And what are the particular causes of Simpson's Paradox within this age group?
# <br>
# 5. We will look at the data more carefully by following an analysis by epidemiologist Jeffrey Morris, who refuted the unreliable journalist's claims within days of their publication. He divides the excessively wide 10-59 year age group into 10 groups, each 5 years wide.
# <br>
# To estimate normal, pre-pandemic death rates in these groups, he uses 2019 data from the U.K. Office of National Statistics. To estimate the vaccination rate in each group, he uses data from the coronavirus dashboard provided by the U.K. Health Security Agency. Finally, to estimate the fraction of people in each age group, he uses data from a web site called PopulationPyramid, which organizes and publishes data from the United Nations Department of Economic and Social Affairs. Not to get lost in the details, these are all reliable data sources.
# <br>
# We want to compute the distribution of ages in the vaccinated and unvaccinated groups at the beginning of August 2021 (choosing a point near the middle of the interval in the original graph). Calculate the share of people per age group of the 10-59 year old, the share of vaccinated people per age group and the share of unvaccinated people per age group! Plot the share of vaccinated and unvaccinated along the age groups and comment!
# <br>
# 6. Now, for the sake of this example, let's imagine that there are no deaths due to COVID, and no deaths due to the vaccine. Based only on the distribution of ages and the death rates from 2019, compute the expected death rates for the vaccinated and unvaccinated groups!
# <br>
# 7. So far we have used only data that was publicly available in November 2021, but if we take advantage of more recent data, we can get a clearer picture of what was happening then and what has happened since. In more recent reports, data from the U.K. Office of National Statistics are broken into smaller age groups. Instead of one group from ages 10 to 59, we have three groups from 18 to 39, 40 to 49, and 50 to 59. Use the dataset "referencetable20220516accessiblecorrected.xlsx" from the [U.K. Office for National Statistics](https://www.ons.gov.uk/file?uri=/peoplepopulationandcommunity/birthsdeathsandmarriages/deaths/datasets/deathsbyvaccinationstatusengland/deathsoccurringbetween1january2021and31march2022/referencetable20220516accessiblecorrected.xlsx) to show similar plots as in task 3!
# ***

# %%
## task 1
# !pip install -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt #ensure that the required packages are installed
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: mglearn>=0.2.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (0.2.0)
# Requirement already satisfied: dowhy in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (0.8)
# Requirement already satisfied: empiricaldist>=0.7.2 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 17)) (0.9.0)
# Requirement already satisfied: stargazer in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 18)) (0.0.7)
# Requirement already satisfied: wrds in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (3.5.0)
# Requirement already satisfied: newsapi-python in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 20)) (0.2.7)
# Requirement already satisfied: plotnine in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 21)) (0.15.3)
# Requirement already satisfied: tables in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from -r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (3.11.1)
# Requirement already satisfied: numpy in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (2.4.4)
# Requirement already satisfied: matplotlib in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (3.10.9)
# Requirement already satisfied: scikit-learn in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.8.0)
# Requirement already satisfied: pandas in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (2.2.3)
# Requirement already satisfied: pillow in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (12.2.0)
# Requirement already satisfied: cycler in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (0.12.1)
# Requirement already satisfied: imageio in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (2.37.3)
# Requirement already satisfied: joblib in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.5.3)
# Requirement already satisfied: scipy in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (1.17.1)
# Requirement already satisfied: statsmodels in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (0.14.6)
# Requirement already satisfied: networkx>=2.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (3.6.1)
# Requirement already satisfied: sympy>=1.4 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (1.14.0)
# Requirement already satisfied: pydot>=1.4 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (4.0.1)
# Requirement already satisfied: ipython<=9.8.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (9.8.0)
# Requirement already satisfied: psycopg2-binary<2.10,>=2.9 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (2.9.12)
# Requirement already satisfied: sqlalchemy<2.1,>=2 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (2.0.49)
# Requirement already satisfied: decorator>=4.3.2 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (5.14.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from pandas->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from pandas->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (2026.1.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from pandas->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (2026.1)
# Requirement already satisfied: wcwidth in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from sqlalchemy<2.1,>=2->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (4.15.0)
# Requirement already satisfied: requests<3.0.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from newsapi-python->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 20)) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from requests<3.0.0->newsapi-python->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 20)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from requests<3.0.0->newsapi-python->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 20)) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from requests<3.0.0->newsapi-python->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 20)) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from requests<3.0.0->newsapi-python->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 20)) (2026.4.22)
# Requirement already satisfied: mizani~=0.14.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from plotnine->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 21)) (0.14.4)
# Requirement already satisfied: numexpr>=2.6.2 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (2.14.1)
# Requirement already satisfied: packaging in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (26.1)
# Requirement already satisfied: py-cpuinfo in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (4.1.2)
# Requirement already satisfied: ndindex in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from blosc2>=2.3.0->tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (1.10.1)
# Requirement already satisfied: msgpack in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from blosc2>=2.3.0->tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (1.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from jedi>=0.18.1->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.8.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (3.3.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from pexpect>4.3->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from statsmodels->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (1.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from sympy>=1.4->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (1.3.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from scikit-learn->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (3.6.0)
# Requirement already satisfied: numexpr>=2.6.2 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (2.14.1)
# Requirement already satisfied: packaging in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (26.1)
# Requirement already satisfied: py-cpuinfo in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (9.0.0)
# Requirement already satisfied: blosc2>=2.3.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (4.1.2)
# Requirement already satisfied: ndindex in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from blosc2>=2.3.0->tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (1.10.1)
# Requirement already satisfied: msgpack in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from blosc2>=2.3.0->tables->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 22)) (1.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from jedi>=0.18.1->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.8.6)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.5.0)
# Requirement already satisfied: pyparsing>=3 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from matplotlib->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (3.3.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from pexpect>4.3->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.7.0)
# Requirement already satisfied: six>=1.5 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from stack_data>=0.6.0->ipython<=9.8.0->wrds->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 19)) (0.2.3)
# Requirement already satisfied: patsy>=0.5.6 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from statsmodels->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (1.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from sympy>=1.4->dowhy->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 16)) (1.3.0)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /Users/kajetan/Projects/TUdortmund/DAI/.venv/lib/python3.14/site-packages (from scikit-learn->mglearn>=0.2.0->-r https://raw.githubusercontent.com/firrm/DAI/main/requirements_colab.txt (line 15)) (3.6.0)
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
filename = "https://raw.githubusercontent.com/firrm/DAI/main/data/datasetfinalcorrected3.xlsx"
df = pd.read_excel(
    filename,
    sheet_name="Table 4",
    skiprows=3,
    skipfooter=12,
)
df.tail()
# Out:
#     Week ending  Week number Vaccination status Age group  Number of deaths  \
# 603  2021-09-17           37        Second dose       80+              4000
# 604  2021-09-24           38        Second dose     10-59               400
# 605  2021-09-24           38        Second dose     60-69               638
# 606  2021-09-24           38        Second dose     70-79              1553
# 607  2021-09-24           38        Second dose       80+              3839
#
#      Population  Percentage of total age-group population  \
# 603     2437192                                      96.3
# 604    17924346                                      66.4
# 605     4973647                                      93.8
# 606     4171936                                      96.3
# 607     2439328                                      96.3
#
#     Age-specific rate per 100,000 Unnamed: 8 Lower confidence limit  \
# 603                         164.1        NaN                  159.1
# 604                           2.2        NaN                      2
# 605                          12.8        NaN                   11.9
# 606                          37.2        NaN                   35.4
# 607                         157.4        NaN                  152.4
#
#     Upper confidence limit
# 603                  169.3
# 604                    2.5
# 605                   13.9
# 606                   39.1
# 607                  162.4

# %%
df["Age-specific rate per 100,000"].replace(":", np.nan, inplace=True)
# Out:
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/4056399107.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age-specific rate per 100,000"].replace(":", np.nan, inplace=True)
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/4056399107.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Age-specific rate per 100,000"].replace(":", np.nan, inplace=True)

# %%
df.columns
# Out:
# Index(['Week ending', 'Week number', 'Vaccination status', 'Age group',
#        'Number of deaths', 'Population',
#        'Percentage of total age-group population',
#        'Age-specific rate per 100,000', 'Unnamed: 8', 'Lower confidence limit',
#        'Upper confidence limit'],
#       dtype='object')

# %%
table = df.pivot_table(
    index="Week ending",
    columns=["Vaccination status", "Age group"],
    values="Age-specific rate per 100,000",
    aggfunc="median",
)
table.head()
# Out:
# Vaccination status 21 days or more after first dose                      \
# Age group                                     10-59 60-69  70-79    80+
# Week ending
# 2021-01-08                                      NaN   NaN    NaN  190.1
# 2021-01-15                                      2.7   NaN  104.3  186.8
# 2021-01-22                                      2.0   7.5  107.2  175.7
# 2021-01-29                                      2.3  14.4   65.0  152.3
# 2021-02-05                                      1.5  15.0   59.9  157.5
#
# Vaccination status Second dose                   Unvaccinated               \
# Age group                10-59 60-69 70-79   80+        10-59 60-69  70-79
# Week ending
# 2021-01-08                 NaN   NaN   NaN   8.1          3.7  27.3   69.8
# 2021-01-15                 NaN   NaN   NaN  32.8          4.0  30.1   78.8
# 2021-01-22                 NaN   NaN   NaN  52.8          4.1  30.8   95.5
# 2021-01-29                 NaN   NaN   NaN  53.4          3.7  29.2  112.2
# 2021-02-05                 NaN   NaN   NaN  64.7          3.6  26.5  168.2
#
# Vaccination status         Within 21 days of first dose
# Age group              80+                        10-59 60-69 70-79    80+
# Week ending
# 2021-01-08           413.4                          0.7  10.8  32.6   84.5
# 2021-01-15           645.1                          1.9  19.7  25.8  100.6
# 2021-01-22          1198.0                          1.7  21.5  25.4  122.0
# 2021-01-29          1571.9                          1.8  18.3  26.3  180.9
# 2021-02-05          1456.1                          3.4  11.9  22.8  223.0

# %%
## task 5

index = [
    "10-14",
    "15-19",
    "20-24",
    "25-29",
    "30-34",
    "35-39",
    "40-44",
    "45-49",
    "50-54",
    "55-59",
]
rate = [8.8, 23.1, 39.1, 48.4, 66.9, 97.3, 143.3, 219.6, 321.5, 478.2]
pct_vax = [0, 26.7, 59.6, 59.7, 63.3, 63.3, 74.6, 80.5, 85.6, 88.2]
pct_pop = [5.9, 5.5, 6.2, 6.8, 6.7, 6.6, 6.0, 6.6, 7.0, 6.6]

sheet = pd.DataFrame(dict(rate=rate, pct_vax=pct_vax, pct_pop=pct_pop), index)

# %%
## task 7

filename = "https://raw.githubusercontent.com/firrm/DAI/main/data/referencetable20220516accessiblecorrected.xlsx"
df = pd.read_excel(
    filename,
    sheet_name="Table 2",
    skiprows=3,
)
df.tail()
# Out:
#            Cause of Death  Year  Month Age group  \
# 2200  Non-COVID-19 deaths  2022  March       90+
# 2201  Non-COVID-19 deaths  2022  March       90+
# 2202  Non-COVID-19 deaths  2022  March       90+
# 2203  Non-COVID-19 deaths  2022  March       90+
# 2204  Non-COVID-19 deaths  2022  March       90+
#
#                                 Vaccination status Count of deaths  \
# 2200              First dose, at least 21 days ago              57
# 2201            Second dose, less than 21 days ago              <3
# 2202             Second dose, at least 21 days ago             515
# 2203  Third dose or booster, less than 21 days ago              20
# 2204   Third dose or booster, at least 21 days ago            7024
#
#       Person-years Age-standardised mortality rate / 100,000 person-years  \
# 2200           191                                            29817.6
# 2201             7                                                  x
# 2202          1415                                            36402.2
# 2203            67                                            29992.6
# 2204         36170                                            19419.5
#
#      Noted as Unreliable Lower confidence limit Upper confidence limit
# 2200                 NaN                22582.1                  38633
# 2201                 NaN                      x                      x
# 2202                 NaN                33325.7                39686.4
# 2203                 NaN                18312.4                46323.7
# 2204                 NaN                18967.9                  19879

# %%
df["date"] = pd.to_datetime(df["Year"].astype(str) + " " + df["Month"])
rate = "Age-standardised mortality rate / 100,000 person-years"
df["rate"] = df[rate].replace("x", np.nan) / 52
count = "Count of deaths"
df[count].replace("<3", np.nan, inplace=True)
all_cause = df["Cause of Death"] == "All causes"
all_cause_df = df[all_cause]
# Out:
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/391369865.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["date"] = pd.to_datetime(df["Year"].astype(str) + " " + df["Month"])
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/391369865.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["date"] = pd.to_datetime(df["Year"].astype(str) + " " + df["Month"])
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/391369865.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["rate"] = df[rate].replace("x", np.nan) / 52
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/391369865.py:3: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df["rate"] = df[rate].replace("x", np.nan) / 52
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/391369865.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[count].replace("<3", np.nan, inplace=True)
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/391369865.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[count].replace("<3", np.nan, inplace=True)

# %%
table = all_cause_df.pivot_table(
    index="date",
    columns=["Age group", "Vaccination status"],
    values="rate",
    aggfunc="median",
)
table
# Out:
# Age group                                     18-39  \
# Vaccination status First dose, at least 21 days ago
# date
# 2021-01-01                                 2.305769
# 2021-02-01                                 1.313462
# 2021-03-01                                 1.767308
# 2021-04-01                                 2.194231
# 2021-05-01                                 1.573077
# 2021-06-01                                 1.353846
# 2021-07-01                                 0.688462
# 2021-08-01                                 0.894231
# 2021-09-01                                 1.225000
# 2021-10-01                                 1.569231
# 2021-11-01                                 1.407692
# 2021-12-01                                 1.082692
# 2022-01-01                                 0.861538
# 2022-02-01                                 0.621154
# 2022-03-01                                 0.944231
#
# Age group                                             \
# Vaccination status First dose, less than 21 days ago
# date
# 2021-01-01                                  0.886538
# 2021-02-01                                  2.232692
# 2021-03-01                                  0.982692
# 2021-04-01                                  0.875000
# 2021-05-01                                  0.298077
# 2021-06-01                                  0.226923
# 2021-07-01                                  1.084615
# 2021-08-01                                       NaN
# 2021-09-01                                       NaN
# 2021-10-01                                       NaN
# 2021-11-01                                       NaN
# 2021-12-01                                       NaN
# 2022-01-01                                       NaN
# 2022-02-01                                       NaN
# 2022-03-01                                       NaN
#
# Age group                                             \
# Vaccination status Second dose, at least 21 days ago
# date
# 2021-01-01                                       NaN
# 2021-02-01                                       NaN
# 2021-03-01                                       NaN
# 2021-04-01                                  0.663462
# 2021-05-01                                  1.278846
# 2021-06-01                                  1.398077
# 2021-07-01                                  1.525000
# 2021-08-01                                  0.982692
# 2021-09-01                                  0.751923
# 2021-10-01                                  0.657692
# 2021-11-01                                  0.588462
# 2021-08-01                                                  0.0       1271.0
# 2021-09-01                                                573.0       1214.0
# 2021-10-01                                              11842.0       1237.0
# 2021-11-01                                               7466.0       1172.0
# 2021-12-01                                               3301.0       1186.0
# 2022-01-01                                                782.0       1164.0
# 2022-02-01                                                141.0       1036.0
# 2022-03-01                                                 67.0       1141.0
#
# [15 rows x 49 columns]

# %%
unvax_stat = ["Unvaccinated"]

vax_stat = [
    "Second dose, less than 21 days ago",
    "Second dose, at least 21 days ago",
    "Third dose or booster, less than 21 days ago",
    "Third dose or booster, at least 21 days ago",
]
# Unvaccinated
groups = ["18-39", "40-49", "50-59"]
seq = [table[group][unvax_stat] for group in groups]
t = pd.concat(seq, axis=1)
seq = [weight[group][unvax_stat] for group in groups]
w = pd.concat(seq, axis=1)
# make sure that weight is 0 where table is NaN
a = np.where(t.notna(), w, 0)
w = pd.DataFrame(a, index=w.index, columns=w.columns)
# normalize the weights rowwise
total = w.sum(axis=1)
weight_norm = w.divide(total, axis=0)
# compute the weighted sum of table
prod = t.fillna(0) * weight_norm
unvax = prod.sum(axis=1).replace(0, np.nan)

# Vaccinated
groups = ["18-39", "40-49", "50-59"]
seq = [table[group][vax_stat] for group in groups]
t = pd.concat(seq, axis=1)
seq = [weight[group][vax_stat] for group in groups]
w = pd.concat(seq, axis=1)
# make sure that weight is 0 where table is NaN
a = np.where(t.notna(), w, 0)
w = pd.DataFrame(a, index=w.index, columns=w.columns)
# normalize the weights rowwise
total = w.sum(axis=1)
weight_norm = w.divide(total, axis=0)
# compute the weighted sum of table
prod = t.fillna(0) * weight_norm
vax = prod.sum(axis=1).replace(0, np.nan)

vax.plot(color="C1", ls="-", label="Vaccinated")
unvax.plot(color="C0", ls="--", label="Unvaccinated", xlabel="", ylabel="Weekly deaths per 100k", title="All cause death rates, ages 18–59", ylim=[0.1, 4.6])

plt.legend(loc="upper right")

# set axes
high = max(max(unvax), max(vax))
start = pd.Timestamp("2020-12-15")
end = pd.Timestamp("2022-04-01")
ax = plt.gca()
ax.set(ylim=(0, high+0.2), xlim=(start, end))
# Out:
# [(0.0, 4.964293550745933), (611.0, 627.0)]

# %% [markdown]
# Now, produce this plot for all separate age groups (best to use build a function...)!

# %% [markdown]
# ***

# %% [markdown]
# ### Exercise 2
# In your own words, describe the Fundamental Problem of Causal Inference!
#
#
# ***

# %% [markdown]
# ### Exercise 3
# 1. Describe the following 3 DAGs and their implications using e.g. "confounder", "collider", "backdoor path"!
#
# <img src="https://github.com/firrm/DAI/blob/main/assets/confounder.png?raw=1" alt="Confounder" style="width: 350px;"/>
# <img src="https://github.com/firrm/DAI/blob/main/assets/unobserved%20confounder.png?raw=1" alt="Unobserved Confounder" style="width: 350px;"/>
# <img src="https://github.com/firrm/DAI/blob/main/assets/collider.png?raw=1" alt="Collider" style="width: 350px;"/>
# <br>
#
# 2. The following DAG combines the variables female ($F$), discrimination ($D$), occupation ($O$), ability ($A$) and earnings ($Y$). Explain the researcher's model expressed by this DAG!
#
# <img src="https://github.com/firrm/DAI/blob/main/assets/discrimination.png?raw=1" alt="Discrimination" style="width: 350px;"/>
# <br>
#
# 3. Imagine now, we were not interested in the total effect of discrimination on earnings but wanted to control for occupation. Google, for example, claimed that once occupation is taken into account, gender discrimination disappeares (https://www.theverge.com/2022/6/12/23164678/google-pay-118-million-settle-gender-discrimination-lawsuit). What problem would arise if we controlled for occupation?
#
# 4. The following code generates data as suggested by the DAG (hard coded & borrowed from Scott Cunningham). Use this data to show how the discrimination effect apparently changes if we a) only look at the total effect of discrimination, b) control for occupation and thereby open a backdoor path, and c) close this backdoor path while still controlling for $O$.
#
# 5. In 2009 Megan Fox was voted the worst talented, but sexiest actress (https://www.reuters.com/article/idUSTRE5BR3J020091228/?type=entertainmentNews). How are talent and beauty related? Are they? Look at the code below (borrowed from Scott Cunningham & Gabriel Rossman)! Here, talent and beauty are independent, random draws from a standard normal distribution, assigned to 2500 individuals. Consider individuals whose combination (sum) of talent and beauty ranks in the top 85th percentile as moviestars! Show only these moviestars in a scatterplot (talent vs beauty)! Make a judgement regarding the association of talent and beauty! How does the sample selection influence your perception?
# ***

# %%
## task 4

import numpy as np
import pandas as pd
import statsmodels.api as sm

# Reproducibility
np.random.seed(42)

# Data generating process implied by the DAG
tb = pd.DataFrame({
    "female": np.random.binomial(1, 0.5, size=10_000),
    "ability": np.random.normal(size=10_000),
})
tb["discrimination"] = tb["female"].copy()
tb["occupation"] = (
    1
    + 2 * tb["ability"]
    + 0 * tb["female"]
    - 2 * tb["discrimination"]
    + np.random.normal(size=10_000)
 )
tb["wage"] = (
    1
    - 1 * tb["discrimination"]
    + 1 * tb["occupation"]
    + 2 * tb["ability"]
    + np.random.normal(size=10_000)
 )

# (a) Total effect only: Y ~ D
m_a = sm.OLS.from_formula("wage ~ discrimination", data=tb).fit()

# (b) Control for occupation (opens backdoor through ability): Y ~ D + O
m_b = sm.OLS.from_formula("wage ~ discrimination + occupation", data=tb).fit()

# (c) Close backdoor while controlling for O: Y ~ D + O + A
m_c = sm.OLS.from_formula("wage ~ discrimination + occupation + ability", data=tb).fit()

results = pd.DataFrame(
    {
        "coef(discrimination)": [
            m_a.params["discrimination"],
            m_b.params["discrimination"],
            m_c.params["discrimination"],
        ],
        "std.err": [
            m_a.bse["discrimination"],
            m_b.bse["discrimination"],
            m_c.bse["discrimination"],
        ],
    },
    index=[
        "(a) wage ~ discrimination",
        "(b) wage ~ discrimination + occupation",
        "(c) wage ~ discrimination + occupation + ability",
    ],
)

results.round(3)
# Out:
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/1598151578.py:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tb["discrimination"] = tb["female"].copy()
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/1598151578.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tb["occupation"] = (
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3874/1598151578.py:23: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   tb["wage"] = (
#                                                   coef(discrimination)  \
# (a) wage ~ discrimination                                       -3.104
# (b) wage ~ discrimination + occupation                           0.572
# (c) wage ~ discrimination + occupation + ability                -1.017
#
#                                                   std.err
# (a) wage ~ discrimination                           0.085
# (b) wage ~ discrimination + occupation              0.029
# (c) wage ~ discrimination + occupation + ability    0.029

# %%
tb.head(10)
# Out:
#    female   ability  discrimination  occupation      wage
# 0       0 -1.487862               0   -2.591872 -3.783913
# 1       1 -1.125186               1   -3.643047 -5.885880
# 2       1  0.388819               1   -1.254189  0.178262
# 3       1 -1.173873               1   -4.236999 -7.599063
# 4       0  1.112634               0    3.659646  7.028300
# 5       0 -0.071120               0    0.989375  1.147871
# 6       0  0.085595               0    1.662776  1.613592
# 7       1 -0.278373               1   -1.342732 -2.760585
# 8       1  0.772848               1    1.250034  2.251253
# 9       1  0.783160               1    1.444534  4.255548

# %%
## task 5

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Reproducibility
np.random.seed(123)

# Talent and beauty are independent in the full population
moviestar = pd.DataFrame({
    "beauty": np.random.normal(size=2500),
    "talent": np.random.normal(size=2500),
})
moviestar["score"] = moviestar["beauty"] + moviestar["talent"]

# Keep only top 15% by combined score (= above the 85th percentile)
threshold = moviestar["score"].quantile(0.85)
stars = moviestar[moviestar["score"] >= threshold].copy()

# Compare association before vs after selection
corr_full = moviestar[["beauty", "talent"]].corr().loc["beauty", "talent"]
corr_stars = stars[["beauty", "talent"]].corr().loc["beauty", "talent"]

print(f"Correlation in full sample: {corr_full:.3f}")
print(f"Correlation among moviestars (selected sample): {corr_stars:.3f}")

# Scatterplot for selected moviestars only
plt.figure(figsize=(7, 5))
plt.scatter(stars["beauty"], stars["talent"], alpha=0.6)
plt.axvline(0, color="gray", linestyle="--", linewidth=1)
plt.axhline(0, color="gray", linestyle="--", linewidth=1)
plt.title("Talent vs Beauty among selected moviestars")
plt.xlabel("Beauty")
plt.ylabel("Talent")
plt.show()

pd.Series({
    "n_full": len(moviestar),
    "n_moviestars": len(stars),
    "corr_full": round(corr_full, 3),
    "corr_moviestars": round(corr_stars, 3),
})
# Out:
# Correlation in full sample: 0.036
# Correlation among moviestars (selected sample): -0.716
# /var/folders/wx/b_h8zt7d5ps2y7dhc2qj9pgc0000gn/T/ipykernel_3969/395637773.py:15: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   moviestar["score"] = moviestar["beauty"] + moviestar["talent"]
# n_full             2500.000
# n_moviestars        375.000
# corr_full             0.036
# corr_moviestars      -0.716
# dtype: float64

# %% [markdown]
# ### References
# ***
#
# [1] Cunningham, S. (2021). Causal Inference: The Mixtape. Yale University Press. https://doi.org/10.2307/j.ctv1c29t27
#
# [2] Garreta, R., & Moncecchi, G. (2013). Learning scikit-learn: machine learning in python. Packt Publishing Ltd.
#
# [3] Müller, A. C., & Guido, S. (2016). Introduction to machine learning with Python: a guide for data scientists. " O'Reilly Media, Inc.".
#
# [4] Pedregosa, F., Varoquaux, G., Gramfort, A., Michel, V., Thirion, B., Grisel, O., & Vanderplas, J. (2011). Scikit-learn: Machine learning in Python. the Journal of machine Learning research, 12, 2825-2830.
